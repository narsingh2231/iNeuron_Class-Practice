# %% [markdown]
# <a href="https://colab.research.google.com/github/narsingh2231/iNeuron_Class-Practice/blob/main/EDA/EDA_and_FE_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

warnings.filterwarnings("ignore")


# %matplotlib inline

# %%
df = pd.read_csv("https://raw.githubusercontent.com/narsingh2231/iNeuron_Class-Practice/main/EDA/cleaned_plastore_data.csv")

# %%
df
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10835                                   Sya9a Maroc - FR               FAMILY
# 10836                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10837                             Parkinson Exercices FR              MEDICAL
# 10838                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10839      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
df = df[~df.duplicated(keep = 'first')]

# %%
df
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10835                                   Sya9a Maroc - FR               FAMILY
# 10836                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10837                             Parkinson Exercices FR              MEDICAL
# 10838                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10839      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
# Univariate analysis

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10357 entries, 0 to 10839
# Data columns (total 16 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10357 non-null  object
#  1   Category        10357 non-null  object
#  2   Rating          8892 non-null   float64
#  3   Reviews         10357 non-null  int64
#  4   Size            8831 non-null   float64
#  5   Installs        10357 non-null  int64
#  6   Type            10356 non-null  object
#  7   Price           10357 non-null  float64
#  8   Content Rating  10357 non-null  object
#  9   Genres          10357 non-null  object
#  10  Last Updated    10357 non-null  object
#  11  Current Ver     9047 non-null   object
#  12  Android Ver     9134 non-null   object
#  13  date            10357 non-null  int64
#  14  month           10357 non-null  int64
#  15  year            10357 non-null  int64
# dtypes: float64(3), int64(5), object(8)
# ...

# %%
df.describe()
# Out:
#             Rating       Reviews           Size      Installs         Price  \
# count  8892.000000  1.035700e+04    8831.000000  1.035700e+04  10357.000000
# mean      4.187877  4.059046e+05   21277.437436  1.415776e+07      1.030800
# std       0.522377  2.696778e+06   22547.690005  8.023955e+07     16.278625
# min       1.000000  0.000000e+00      10.000000  0.000000e+00      0.000000
# 25%       4.000000  3.200000e+01    4700.000000  1.000000e+03      0.000000
# 50%       4.300000  1.680000e+03   13000.000000  1.000000e+05      0.000000
# 75%       4.500000  4.641600e+04   29000.000000  1.000000e+06      0.000000
# max       5.000000  7.815831e+07  100000.000000  1.000000e+09    400.000000
#
#                date         month          year
# count  10357.000000  10357.000000  10357.000000
# mean      15.619098      6.397026   2017.382929
# std        9.528658      2.606359      1.112766
# min        1.000000      1.000000   2010.000000
# ...

# %%
df.corr()
# Out:
# <ipython-input-21-2f6f6606aa2c>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#             Rating   Reviews      Size  Installs     Price      date  \
# Rating    1.000000  0.068732  0.082187  0.050886 -0.022355 -0.010102
# Reviews   0.068732  1.000000  0.237880  0.634997 -0.009417 -0.024677
# Size      0.082187  0.237880  1.000000  0.168883 -0.023729 -0.004368
# Installs  0.050886  0.634997  0.168883  1.000000 -0.011147 -0.043546
# Price    -0.022355 -0.009417 -0.023729 -0.011147  1.000000 -0.008480
# date     -0.010102 -0.024677 -0.004368 -0.043546 -0.008480  1.000000
# month     0.016999  0.044681  0.036932  0.053847  0.006490 -0.074367
# year      0.136547  0.075744  0.217284  0.087380 -0.005627 -0.015239
#
#              month      year
# Rating    0.016999  0.136547
# ...

# %%
df.tail()
# Out:
#                                                  App             Category  \
# 10835                               Sya9a Maroc - FR               FAMILY
# 10836               Fr. Mike Schmitz Audio Teachings               FAMILY
# 10837                         Parkinson Exercices FR              MEDICAL
# 10838                  The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10839  iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
#        Rating  Reviews     Size  Installs  Type  Price Content Rating  \
# 10835     4.5       38  53000.0      5000  Free    0.0       Everyone
# 10836     5.0        4   3600.0       100  Free    0.0       Everyone
# 10837     NaN        3   9500.0      1000  Free    0.0       Everyone
# 10838     4.5      114      NaN      1000  Free    0.0     Mature 17+
# 10839     4.5   398307  19000.0  10000000  Free    0.0       Everyone
#
#                   Genres Last Updated Current Ver Android Ver  date  month  \
# ...

# %%
df.sample(15)
# Out:
#                                                      App            Category  \
# 5349      Muslim Pro - Prayer Times, Azan, Quran & Qibla           LIFESTYLE
# 9083                                   Displaying You VR         PHOTOGRAPHY
# 2539                         Low Blood Pressure Symptoms             MEDICAL
# 10207   Profile Tracker - Who Viewed My Facebook Profile              SOCIAL
# 8731                                           Taco Bell           LIFESTYLE
# 355                             Cricket Visual Voicemail       COMMUNICATION
# 8097                                     Amadeus GR & CY       COMMUNICATION
# 3970                                   EMT-B Pocket Prep             MEDICAL
# 6846                                     Bu Hangi Dizi ?                GAME
# 703                           Learn English with Wlingua           EDUCATION
# 6505                            BN Pro BlueICS-b HD Text  LIBRARIES_AND_DEMO
# ...

# %%
df.shape
# Out:
# (10357, 16)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10357 entries, 0 to 10839
# Data columns (total 16 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10357 non-null  object
#  1   Category        10357 non-null  object
#  2   Rating          8892 non-null   float64
#  3   Reviews         10357 non-null  int64
#  4   Size            8831 non-null   float64
#  5   Installs        10357 non-null  int64
#  6   Type            10356 non-null  object
#  7   Price           10357 non-null  float64
#  8   Content Rating  10357 non-null  object
#  9   Genres          10357 non-null  object
#  10  Last Updated    10357 non-null  object
#  11  Current Ver     9047 non-null   object
#  12  Android Ver     9134 non-null   object
#  13  date            10357 non-null  int64
#  14  month           10357 non-null  int64
#  15  year            10357 non-null  int64
# dtypes: float64(3), int64(5), object(8)
# ...

# %%
df.describe()
# Out:
#             Rating       Reviews           Size      Installs         Price  \
# count  8892.000000  1.035700e+04    8831.000000  1.035700e+04  10357.000000
# mean      4.187877  4.059046e+05   21277.437436  1.415776e+07      1.030800
# std       0.522377  2.696778e+06   22547.690005  8.023955e+07     16.278625
# min       1.000000  0.000000e+00      10.000000  0.000000e+00      0.000000
# 25%       4.000000  3.200000e+01    4700.000000  1.000000e+03      0.000000
# 50%       4.300000  1.680000e+03   13000.000000  1.000000e+05      0.000000
# 75%       4.500000  4.641600e+04   29000.000000  1.000000e+06      0.000000
# max       5.000000  7.815831e+07  100000.000000  1.000000e+09    400.000000
#
#                date         month          year
# count  10357.000000  10357.000000  10357.000000
# mean      15.619098      6.397026   2017.382929
# std        9.528658      2.606359      1.112766
# min        1.000000      1.000000   2010.000000
# ...

# %%
df.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver', 'date', 'month', 'year'],
#       dtype='object')

# %% [markdown]
# # Univariate analysis

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [App, Category, Rating, Reviews, Size, Installs, Type, Price, Content Rating, Genres, Last Updated, Current Ver, Android Ver, date, month, year]
# Index: []

# %%
df[df.duplicated("App")]
# Out:
#                                             App       Category  Rating  \
# 285                Quick PDF Scanner + OCR FREE       BUSINESS     4.2
# 293      OfficeSuite : Free Office + PDF Editor       BUSINESS     4.3
# 294                                       Slack       BUSINESS     4.4
# 382    Messenger – Text and Video Chat for Free  COMMUNICATION     4.0
# 383               imo free video calls and chat  COMMUNICATION     4.3
# ...                                         ...            ...     ...
# 10646                         Motorola FM Radio  VIDEO_PLAYERS     3.9
# 10714                        FarmersOnly Dating         DATING     3.0
# 10719        Firefox Focus: The privacy browser  COMMUNICATION     4.4
# 10729                               FP Notebook        MEDICAL     4.5
# 10752            Slickdeals: Coupons & Shopping       SHOPPING     4.5
#
#         Reviews     Size    Installs  Type  Price Content Rating  \
# ...

# %%
df.drop_duplicates()
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10835                                   Sya9a Maroc - FR               FAMILY
# 10836                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10837                             Parkinson Exercices FR              MEDICAL
# 10838                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10839      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
df = df.drop_duplicates(subset = ['App'], keep = 'first')

# %%
df.shape
# Out:
# (9659, 16)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9659 entries, 0 to 10839
# Data columns (total 16 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             9659 non-null   object
#  1   Category        9659 non-null   object
#  2   Rating          8196 non-null   float64
#  3   Reviews         9659 non-null   int64
#  4   Size            8432 non-null   float64
#  5   Installs        9659 non-null   int64
#  6   Type            9658 non-null   object
#  7   Price           9659 non-null   float64
#  8   Content Rating  9659 non-null   object
#  9   Genres          9659 non-null   object
#  10  Last Updated    9659 non-null   object
#  11  Current Ver     8596 non-null   object
#  12  Android Ver     8667 non-null   object
#  13  date            9659 non-null   int64
#  14  month           9659 non-null   int64
#  15  year            9659 non-null   int64
# dtypes: float64(3), int64(5), object(8)
# ...

# %%
numeric_features = [feature for feature in df.columns if df[feature].dtype !="O"]

# %%
numeric_features
# Out:
# ['Rating', 'Reviews', 'Size', 'Installs', 'Price', 'date', 'month', 'year']

# %%
catagorical_features = [feature for feature in df.columns if df[feature].dtype =="O"]    # separated cat featurs and num features

# %%
catagorical_features
# Out:
# ['App',
#  'Category',
#  'Type',
#  'Content Rating',
#  'Genres',
#  'Last Updated',
#  'Current Ver',
#  'Android Ver']

# %%
df[catagorical_features]
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10835                                   Sya9a Maroc - FR               FAMILY
# 10836                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10837                             Parkinson Exercices FR              MEDICAL
# 10838                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10839      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
df[numeric_features]
# Out:
#        Rating  Reviews     Size  Installs  Price  date  month  year
# 0         4.1      159  19000.0     10000    0.0     7      1  2018
# 1         3.9      967  14000.0    500000    0.0    15      1  2018
# 2         4.7    87510   8700.0   5000000    0.0     1      8  2018
# 3         4.5   215644  25000.0  50000000    0.0     8      6  2018
# 4         4.3      967   2800.0    100000    0.0    20      6  2018
# ...       ...      ...      ...       ...    ...   ...    ...   ...
# 10835     4.5       38  53000.0      5000    0.0    25      7  2017
# 10836     5.0        4   3600.0       100    0.0     6      7  2018
# 10837     NaN        3   9500.0      1000    0.0    20      1  2017
# 10838     4.5      114      NaN      1000    0.0    19      1  2015
# 10839     4.5   398307  19000.0  10000000    0.0    25      7  2018
#
# [9659 rows x 8 columns]

# %%
df['Type'].value_counts()
# Out:
# Free    8902
# Paid     756
# Name: Type, dtype: int64

# %%
df['Type'].value_counts(normalize = True)
# Out:
# Free    0.921723
# Paid    0.078277
# Name: Type, dtype: float64

# %%
df['Type'].value_counts(normalize = True)*100
# Out:
# Free    92.172292
# Paid     7.827708
# Name: Type, dtype: float64

# %%
for col in catagorical_features:
  print(f"{col}:{df[col].value_counts(normalize = True)*100}")
  print("=================================================")
# Out:
# App:Photo Editor & Candy Camera & Grid & ScrapBook    0.010353
# Tic Tac CK                                        0.010353
# INFAMY RO                                         0.010353
# CK Call NEW                                       0.010353
# Ck Coif                                           0.010353
#                                                     ...
# Bike Race Free - Top Motorcycle Racing Games      0.010353
# Dance School Stories - Dance Dreams Come True     0.010353
# 3D Bowling                                        0.010353
# Mind Games Pro                                    0.010353
# iHoroscope - 2018 Daily Horoscope & Astrology     0.010353
# Name: App, Length: 9659, dtype: float64
# ...
# Category:FAMILY                 18.966767
# GAME                    9.928564
# TOOLS                   8.561963
# BUSINESS                4.348276
# MEDICAL                 4.089450
# PERSONALIZATION         3.892743
# PRODUCTIVITY            3.872036
# ...

# %%
sns.countplot(x= df['Type'])
# Out:
# <Axes: xlabel='Type', ylabel='count'>

# %%
for col in catagorical_features:

# %%
sns.countplot(x= df['Content Rating'])
# Out:
# <Axes: xlabel='Content Rating', ylabel='count'>

# %%
# Catogorical Colums
plt.figure(figsize =(20,15))
plt.suptitle("Univariate Analysis of Catogorical Features", fontsize = 20, fontweight = 'bold', alpha = 0.8, y = 1)
category = ['Type', 'Content Rating']
for i in range(0, len(category)):
  plt.subplot(2,2, i+1)
  sns.countplot(x = df[category[i]], palette = 'Set2')
  plt.xlabel(category[i])
  plt.xticks(rotation = 45)
  plt.tight_layout()

# %%
numeric_features
# Out:
# ['Rating', 'Reviews', 'Size', 'Installs', 'Price', 'date', 'month', 'year']

# %%
sns.kdeplot(df['Price'])
# Out:
# <Axes: xlabel='Price', ylabel='Density'>

# %%
sns.kdeplot(df['Reviews'])
# Out:
# <Axes: xlabel='Reviews', ylabel='Density'>

# %%
sns.kdeplot(df['Rating'])
# Out:
# <Axes: xlabel='Rating', ylabel='Density'>

# %%
# Numerical Colums
plt.figure(figsize =(15,15))
plt.suptitle("Univariate Analysis of Numerical Features", fontsize = 20, fontweight = 'bold', alpha = 0.8, y = 1)

for i in range(0, len(numeric_features)):
  plt.subplot(5,3, i+1)
  sns.distplot(x = df[numeric_features[i]])  #,shade = True, color = 'r'
  plt.xlabel(numeric_features[i])

  plt.tight_layout()

# %%
# Numerical Colums
plt.figure(figsize =(15,15))
plt.suptitle("Univariate Analysis of Numerical Features", fontsize = 20, fontweight = 'bold', alpha = 0.8, y = 1)

for i in range(0, len(numeric_features)):
  plt.subplot(5,3, i+1)
  sns.kdeplot(x = df[numeric_features[i]],shade = True, color = 'r')  #
  plt.xlabel(numeric_features[i])

  plt.tight_layout()

# %% [markdown]
# # most papular category in App

# %%
df['App'].value_counts().plot.pie()
# Out:
# <Axes: ylabel='App'>

# %%
df['App'].value_counts().plot.pie(y = df['App'])
# Out:
# <Axes: ylabel='App'>

# %%
catagorical_features
# Out:
# ['App',
#  'Category',
#  'Type',
#  'Content Rating',
#  'Genres',
#  'Last Updated',
#  'Current Ver',
#  'Android Ver']

# %%
df['Type'].value_counts().plot.pie()
# Out:
# <Axes: ylabel='Type'>

# %%
df['Category'].value_counts().plot.pie(y = df['Category'], figsize = (15,15), autopct = '%1.1f%%' )
# Out:
# <Axes: ylabel='Category'>

# %%
df['Content Rating'].value_counts().plot.pie(y = df['Content Rating'], figsize = (15,15), autopct = '%1.1f%%' )
# Out:
# <Axes: ylabel='Content Rating'>

# %% [markdown]
# # Top 10 Category

# %%
df_cat = df["Category"].value_counts()[:10]

# %%
category = pd.DataFrame(df["Category"].value_counts())
category.rename(columns = {'Category' : 'Count'}, inplace = True)

# %%
plt.figure(figsize = (15,6))
sns.barplot(x = df_cat, y = 'Count', data =  category[:10], palette= 'hls')
plt.title('Top 10 App Categories')
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# # which category is having largest number of installations

# %%
df_cat_installs = df.groupby(['Category'])['Installs'].sum().sort_values(ascending = False).reset_index()

# %%
df2 = df_cat_installs.head(10)

# %%
sns.barplot(x= "Installs", y = "Category", data = df2)
# Out:
# <Axes: xlabel='Installs', ylabel='Category'>

# %%
plt.figure(figsize = (14,10))
sns.set_context("talk")
sns.set_style("darkgrid")

ax = sns.barplot(x = 'Installs' , y = 'Category' , data = df2 )
ax.set_xlabel('No. of Installations in Billions')
ax.set_ylabel('')
ax.set_title("Most Popular Categories in Play Store", size = 20)
# Out:
# Text(0.5, 1.0, 'Most Popular Categories in Play Store')

# %% [markdown]
# # What are the Top 5 most installed Apps in Each popular Categories??

# %%
df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#    Reviews     Size  Installs  Type  Price Content Rating  \
# 0      159  19000.0     10000  Free    0.0       Everyone
# 1      967  14000.0    500000  Free    0.0       Everyone
# 2    87510   8700.0   5000000  Free    0.0       Everyone
# 3   215644  25000.0  50000000  Free    0.0           Teen
# 4      967   2800.0    100000  Free    0.0       Everyone
#
#                       Genres Last Updated Current Ver Android Ver  date  \
# 0               Art & Design   2018-01-07       1.0.0       4.0.3     7
# ...

# %%
# installs, app, Category     # multivariable

# %%
df3 = df.groupby(['Category', 'App'])['Installs'].sum().reset_index()

# %%
df3
# Out:
#             Category                                                App  \
# 0     ART_AND_DESIGN                           350 Diy Room Decor Ideas
# 1     ART_AND_DESIGN    3D Color Pixel by Number - Sandbox Art Coloring
# 2     ART_AND_DESIGN                            AJ Styles HD Wallpapers
# 3     ART_AND_DESIGN  AJ Styles Wallpaper 2018 - AJ Styles HD Wallpaper
# 4     ART_AND_DESIGN                              Ai illustrator viewer
# ...              ...                                                ...
# 9654         WEATHER                                      Yahoo Weather
# 9655         WEATHER  Yahoo! Weather for SH Forecast for understandi...
# 9656         WEATHER                                     Yandex.Weather
# 9657         WEATHER                         weather - weather forecast
# 9658         WEATHER                     wetter.com - Weather and Radar
#
#       Installs
# 0        10000
# 1       100000
# 2         5000
# 3         1000
# 4       100000
# ...

# %%
df3 = df3.sort_values('Installs', ascending= False)

# %%
df3[df3.Category == 'GAME'][:5]
# Out:
#      Category               App    Installs
# 4773     GAME    Subway Surfers  1000000000
# 4167     GAME  Candy Crush Saga   500000000
# 4628     GAME               Pou   500000000
# 4802     GAME      Temple Run 2   500000000
# 4580     GAME    My Talking Tom   500000000

# %%
df3[df3.Category == 'FAMILY'][:5]
# Out:
#      Category                            App   Installs
# 3333   FAMILY               Tom Loves Angela  100000000
# 3290   FAMILY              Talking Tom Cat 2  100000000
# 1976   FAMILY  Bitmoji – Your Personal Emoji  100000000
# 3289   FAMILY                Talking Tom Cat  100000000
# 3287   FAMILY         Talking Tom & Ben News  100000000

# %%
df3[df3.Category == 'PRODUCTIVITY'][:5]
# Out:
#           Category              App    Installs
# 7427  PRODUCTIVITY     Google Drive  1000000000
# 7472  PRODUCTIVITY   Microsoft Word   500000000
# 7425  PRODUCTIVITY  Google Calendar   500000000
# 7364  PRODUCTIVITY          Dropbox   500000000
# 7334  PRODUCTIVITY      Cloud Print   500000000

# %%
df3[df3.Category == 'TOOLS'][:5]
# Out:
#      Category                                                App    Installs
# 8837    TOOLS                                             Google  1000000000
# 9038    TOOLS  Security Master - Antivirus, VPN, AppLock, Boo...   500000000
# 9016    TOOLS                         SHAREit - Transfer & Share   500000000
# 8842    TOOLS                                   Google Translate   500000000
# 8835    TOOLS                       Gboard - the Google Keyboard   500000000

# %%
apps = ['GAME', 'COMMUNICATION', 'PRODUCTIVITY', 'SOCIAL' ]
sns.set_context("poster")
sns.set_style("darkgrid")

plt.figure(figsize=(40,30))

for i,app in enumerate(apps):
    df4 = df3[df3.Category == app]
    df5 = df4.head(5)
    plt.subplot(4,2,i+1)
    sns.barplot(data= df5,x= 'Installs' ,y='App' )
    plt.xlabel('Installation in Millions')
    plt.ylabel('')
    plt.title(app,size = 20)

plt.tight_layout()
plt.subplots_adjust(hspace= .3)
plt.show()

# %% [markdown]
# # How many apps are there on Playstore which get 5 ratings

# %%
# apps, rating

# %%
df_rating = df.groupby(['App'])['Rating'].sum().sort_values(ascending = False).reset_index()

# %%
df_rating
# Out:
#                                                    App  Rating
# 0                            Comunidad De Fe Minitries     5.0
# 1                                      Tablet Reminder     5.0
# 2                                Noticias FC Barcelona     5.0
# 3     Superheroes, Marvel, DC, Comics, TV, Movies News     5.0
# 4                    DC N COMPANY ENTERTAINMENT RADIO!     5.0
# ...                                                ...     ...
# 9654                              DK Childcare Centers     0.0
# 9655                         Pediatric Emergency Guide     0.0
# 9656                                     Pekalongan CJ     0.0
# 9657                        Penn State Health OnDemand     0.0
# 9658              "i DT" Fútbol. Todos Somos Técnicos.     0.0
#
# [9659 rows x 2 columns]

# %%
df_rating[df_rating.Rating == 5.0]
# Out:
#                                                   App  Rating
# 0                           Comunidad De Fe Minitries     5.0
# 1                                     Tablet Reminder     5.0
# 2                               Noticias FC Barcelona     5.0
# 3    Superheroes, Marvel, DC, Comics, TV, Movies News     5.0
# 4                   DC N COMPANY ENTERTAINMENT RADIO!     5.0
# ..                                                ...     ...
# 266                     American Girls Mobile Numbers     5.0
# 267                                         daskal.eu     5.0
# 268                         Free coupons and vouchers     5.0
# 269                                      Bk Usha behn     5.0
# 270                           Asha Ek Hope - ALS/ MND     5.0
#
# [271 rows x 2 columns]

# %%
df_rating2 = df.groupby(['Category','Installs', 'App'])['Rating'].sum().sort_values(ascending = False).reset_index()

# %%
df.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver', 'date', 'month', 'year'],
#       dtype='object')

# %%
plt.figure(figsize = (15,20))
sns.scatterplot(data = df , y = 'Category', x = 'Price')
# Out:
# <Axes: xlabel='Price', ylabel='Category'>

# %% [markdown]
# ## which Category app users are reviewing the most??

# %%
df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#    Reviews     Size  Installs  Type  Price Content Rating  \
# 0      159  19000.0     10000  Free    0.0       Everyone
# 1      967  14000.0    500000  Free    0.0       Everyone
# 2    87510   8700.0   5000000  Free    0.0       Everyone
# 3   215644  25000.0  50000000  Free    0.0           Teen
# 4      967   2800.0    100000  Free    0.0       Everyone
#
#                       Genres Last Updated Current Ver Android Ver  date  \
# 0               Art & Design   2018-01-07       1.0.0       4.0.3     7
# ...

# %%
df_reveiws = df.groupby(['Category', 'App'])['Reviews'].sum().sort_values(ascending = False).reset_index()

# %%
df_reveiws.head(10)
# Out:
#         Category                                                App   Reviews
# 0         SOCIAL                                           Facebook  78158306
# 1  COMMUNICATION                                 WhatsApp Messenger  69119316
# 2         SOCIAL                                          Instagram  66577313
# 3  COMMUNICATION           Messenger – Text and Video Chat for Free  56642847
# 4           GAME                                     Clash of Clans  44891723
# 5          TOOLS            Clean Master- Space Cleaner & Antivirus  42916526
# 6           GAME                                     Subway Surfers  27722264
# 7  VIDEO_PLAYERS                                            YouTube  25655305
# 8          TOOLS  Security Master - Antivirus, VPN, AppLock, Boo...  24900999
# 9           GAME                                       Clash Royale  23133508

# %%
df.groupby('Category').agg({'Installs':"sum", 'Reviews': 'sum'}).reset_index()       # another way of groupby syntax
# Out:
#                Category     Installs    Reviews
# 0        ART_AND_DESIGN    114338100    1419203
# 1     AUTO_AND_VEHICLES     53130211    1163666
# 2                BEAUTY     27197050     396240
# 3   BOOKS_AND_REFERENCE   1665969576   16721314
# 4              BUSINESS    697164865    9890245
# 5                COMICS     44981150    2342071
# 6         COMMUNICATION  11038276251  285811368
# 7                DATING    140926107    3623544
# 8             EDUCATION    352952000   13364148
# 9         ENTERTAINMENT   2113660000   34762650
# 10               EVENTS     15973161     161018
# 11               FAMILY   4427941505  143825488
# 12              FINANCE    455348734   12662106
# 13       FOOD_AND_DRINK    211798751    6325028
# 14                 GAME  13878924415  622298709
# 15   HEALTH_AND_FITNESS   1144022512   21361355
# 16       HOUSE_AND_HOME     97212461    1929847
# 17   LIBRARIES_AND_DEMO     52995910     906831
# 18            LIFESTYLE    503823539   11832671
# ...

# %%
df.groupby('Type').agg({'Installs':sum})
# Out:
#          Installs
# Type
# Free  75065572646
# Paid     57364881

# %%
fig, ax = plt.subplots(1,2,figsize=(20,7))
df.value_counts('Type').plot.pie(y='Type',startangle=90, explode=(0.2,0), title='Percentage of the Free App and Paid App', legend=False, autopct='%.2f', ax=ax[0])
ax[0].set(ylabel='Type of Apps')
df.groupby('Type').agg({'Installs':sum}).plot.pie(y='Installs', startangle=90, explode=(0.2,0), title='Percentage of Installs Number for Free App and Paid App', legend=False, autopct='%.2f', ax=ax[1])
# Out:
# <Axes: title={'center': 'Percentage of Installs Number for Free App and Paid App'}, ylabel='Installs'>

# %%
df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#    Reviews     Size  Installs  Type  Price Content Rating  \
# 0      159  19000.0     10000  Free    0.0       Everyone
# 1      967  14000.0    500000  Free    0.0       Everyone
# 2    87510   8700.0   5000000  Free    0.0       Everyone
# 3   215644  25000.0  50000000  Free    0.0           Teen
# 4      967   2800.0    100000  Free    0.0       Everyone
#
#                       Genres Last Updated Current Ver Android Ver  date  \
# 0               Art & Design   2018-01-07       1.0.0       4.0.3     7
# ...

# %%
plt.figure(figsize =(12,12))
sns.boxplot(x= 'Installs', y = 'Rating', data = df)
plt.xticks(size = 15, rotation = 90)
plt.show()

# %%
plt.figure(figsize =(12,12))
sns.boxplot(x= 'Category', y = 'Rating', data = df)
plt.xticks(size = 15, rotation = 90)
plt.show()

# %% [markdown]
# # Which Category having largest size

# %%
plt.figure(figsize = (12,15))
plt.xticks(rotation = 90)
plt.yticks(rotation = 90)
sns.barplot(x = 'Category', y = 'Size', data = df)
plt.show()
